# %%
# %matplotlib inline
import matplotlib.pyplot as plt  # type: ignore
import numpy as np
import numpy.typing as npt

from fixed_basis import GaussianBasisMixin, PolynomialBasisMixin

# %%
low = -10
high = 10
num = 1000
x = np.linspace(low, high, num)

# %%
phi = GaussianBasisMixin(low=low, high=high, num=10, stddev=1.).phi(x)
plt.plot(x, phi)
# Out:
# stddev: 1.0
# [<matplotlib.lines.Line2D at 0x12d7b5040>,
#  <matplotlib.lines.Line2D at 0x12d7b50a0>,
#  <matplotlib.lines.Line2D at 0x12d7b51c0>,
#  <matplotlib.lines.Line2D at 0x12d7b52e0>,
#  <matplotlib.lines.Line2D at 0x12d7b5400>,
#  <matplotlib.lines.Line2D at 0x12d7b5520>,
#  <matplotlib.lines.Line2D at 0x12d7b5640>,
#  <matplotlib.lines.Line2D at 0x12d7b5760>,
#  <matplotlib.lines.Line2D at 0x12d7b5880>,
#  <matplotlib.lines.Line2D at 0x12d7b59a0>]

# %%
phi = PolynomialBasisMixin(m_degrees=10).phi(x)
plt.plot(x, phi)
# Out:
# [<matplotlib.lines.Line2D at 0x12d89b0a0>,
#  <matplotlib.lines.Line2D at 0x12d89b100>,
#  <matplotlib.lines.Line2D at 0x12d89b220>,
#  <matplotlib.lines.Line2D at 0x12d89b340>,
#  <matplotlib.lines.Line2D at 0x12d89b460>,
#  <matplotlib.lines.Line2D at 0x12d89b580>,
#  <matplotlib.lines.Line2D at 0x12d89b6a0>,
#  <matplotlib.lines.Line2D at 0x12d89b7c0>,
#  <matplotlib.lines.Line2D at 0x12d89b8e0>,
#  <matplotlib.lines.Line2D at 0x12d89ba00>]
