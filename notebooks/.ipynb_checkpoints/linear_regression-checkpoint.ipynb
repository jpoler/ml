# %%
# %matplotlib inline
import matplotlib.pyplot as plt  # type: ignore
import numpy as np
import numpy.typing as npt

from data.sin import sin_curve, sin_data
from linear_regression import GaussianBasisLeastSquaresRegression, PolynomialBasisLeastSquaresRegression

# %%
s_curve = sin_curve()
s_data = sin_data(n_train=200, n_test=100)

# %%
model = PolynomialBasisLeastSquaresRegression(m_degrees=10)
model.fit(s_data.x_train, s_data.y_train)

y_predictions = model.predict(s_data.x_test)

plt.plot(
    s_curve.x,
    s_curve.y,
    "b-",
    s_data.x_train,
    s_data.y_train,
    "go",
    s_data.x_test,
    y_predictions,
    "ro",
)
# Out:
# [<matplotlib.lines.Line2D at 0x11fcd7340>,
#  <matplotlib.lines.Line2D at 0x11fcd7250>,
#  <matplotlib.lines.Line2D at 0x11fcd7460>]

# %%
model = PolynomialBasisLeastSquaresRegression(
    m_degrees=10, regularization_coefficient=3.0
)
model.fit(s_data.x_train, s_data.y_train)

y_predictions = model.predict(s_data.x_test)

plt.plot(
    s_curve.x,
    s_curve.y,
    "b-",
    s_data.x_train,
    s_data.y_train,
    "go",
    s_data.x_test,
    y_predictions,
    "ro",
)
# Out:
# [<matplotlib.lines.Line2D at 0x11fe4b760>,
#  <matplotlib.lines.Line2D at 0x11fe4b730>,
#  <matplotlib.lines.Line2D at 0x11fe4b910>]

# %%
model = GaussianBasisLeastSquaresRegression(
    low=0.0, high=2*np.pi, num=10, stddev=.6
)
model.fit(s_data.x_train, s_data.y_train)

y_predictions = model.predict(s_data.x_test)

plt.plot(
    s_curve.x,
    s_curve.y,
    "b-",
    s_data.x_train,
    s_data.y_train,
    "go",
    s_data.x_test,
    y_predictions,
    "ro",
)
# Out:
# stddev: 0.6
# stddev: 0.6
# [<matplotlib.lines.Line2D at 0x11ff1aa90>,
#  <matplotlib.lines.Line2D at 0x11ff1aa60>,
#  <matplotlib.lines.Line2D at 0x11ff1ac40>]
