# %%
# %matplotlib inline
import matplotlib.pyplot as plt  # type: ignore
import numpy as np
import numpy.typing as npt

from data.sin import sin_curve, sin_data
from linear_regression import PolynomialBasisLeastSquaresRegression

# %%
s_curve = sin_curve()
s_data = sin_data(n_train=200, n_test=100)

# %%
model = PolynomialBasisLeastSquaresRegression(m_degrees=10)
model.fit(s_data.x_train, s_data.y_train)

y_predictions = model.predict(s_data.x_test)

plt.plot(
    s_curve.x,
    s_curve.y,
    "b-",
    s_data.x_train,
    s_data.y_train,
    "go",
    s_data.x_test,
    y_predictions,
    "ro",
)
# Out:
# [<matplotlib.lines.Line2D at 0x113affbb0>,
#  <matplotlib.lines.Line2D at 0x113affb80>,
#  <matplotlib.lines.Line2D at 0x113affd60>]

# %%
model = PolynomialBasisLeastSquaresRegression(
    m_degrees=10, regularization_coefficient=3.0
)
model.fit(s_data.x_train, s_data.y_train)

y_predictions = model.predict(s_data.x_test)

plt.plot(
    s_curve.x,
    s_curve.y,
    "b-",
    s_data.x_train,
    s_data.y_train,
    "go",
    s_data.x_test,
    y_predictions,
    "ro",
)
# Out:
# [<matplotlib.lines.Line2D at 0x113bc4d60>,
#  <matplotlib.lines.Line2D at 0x113bc4d30>,
#  <matplotlib.lines.Line2D at 0x113bc4f10>]
